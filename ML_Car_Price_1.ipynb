# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanketh00/Loan-Prediction/blob/main/ML_Car_Price_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
training_df = pd.read_csv('/content/sample_data/ML_Car_Price_1.csv')


# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#     Year    Kms  Showroom_Price  Present_Price
# 0 2000.0 1000.0             5.0            5.0
# 1 2000.0 2000.0             5.0            4.9
# 2 2000.0 3000.0             5.0            4.9
# 3 2000.0 4000.0             5.0            4.9
# 4 2000.0 5000.0             5.0            4.8

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# True
# Year              2
# Kms               2
# Showroom_Price    2
# Present_Price     2
# dtype: int64

# %%
# dropna(inplace = True) will remove all rows containing NULL values from the original DataFrame.
training_df.dropna(inplace = True)

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# Length: 138, dtype: bool

# %%
#Remove all duplicates: The (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.
training_df.drop_duplicates(inplace = True)

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# False
# Year              0
# Kms               0
# Showroom_Price    0
# Present_Price     0
# dtype: int64

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# Length: 136, dtype: bool

# %%
# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#     Year    Kms  Showroom_Price  Present_Price
# 0 2000.0 1000.0             5.0            5.0
# 1 2000.0 2000.0             5.0            4.9
# 2 2000.0 3000.0             5.0            4.9
# 3 2000.0 4000.0             5.0            4.9
# 4 2000.0 5000.0             5.0            4.8

# %%
training_df.corr()
# Out:
#                 Year  Kms  Showroom_Price  Present_Price
# Year             NaN  NaN             NaN            NaN
# Kms              NaN  1.0             NaN           -1.0
# Showroom_Price   NaN  NaN             NaN            NaN
# Present_Price    NaN -1.0             NaN            1.0

# %%
#Delete column 'Year' as it has no correlation with other data and can't be used for training and prediction
del training_df['Year']
del training_df['Showroom_Price']
print(training_df)
training_df.corr()
# Out:
#          Kms  Present_Price
# 0     1000.0            5.0
# 1     2000.0            4.9
# 2     3000.0            4.9
# 3     4000.0            4.9
# 4     5000.0            4.8
# ..       ...            ...
# 135 132000.0            0.6
# 136 133000.0            0.6
# 137 134000.0            0.5
# 138 135000.0            0.5
# 139 136000.0            0.5
#
# [136 rows x 2 columns]
#                Kms  Present_Price
# Kms            1.0           -1.0
# Present_Price -1.0            1.0

# %%
# Get statistics on the dataset.
training_df.describe()
# Out:
#            Kms  Present_Price
# count    136.0          136.0
# mean   68500.0            2.7
# std    39403.9            1.3
# min     1000.0            0.5
# 25%    34750.0            1.6
# 50%    68500.0            2.7
# 75%   102250.0            3.8
# max   136000.0            5.0

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 100 random points of the dataset.
  random_examples = training_df.sample(n=100)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = random_examples[feature].max()
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.03
epochs = 50
batch_size = 5

# Specify the feature and the label.

#########################################################################
#First execute without below line and observe that predication doesn't match actual values 
#as Kms is a large number compared to Present_Price
#training_df['Kms']=training_df['Kms']/1000

#########################################################################

my_feature = "Kms"  # the total number of rooms on a specific city block.
my_label="Present_Price" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 1s 3ms/step - loss: 65299872.0000 - root_mean_squared_error: 8080.8335
# Epoch 2/50
# 28/28 [==============================] - 0s 2ms/step - loss: 235.9435 - root_mean_squared_error: 15.3605
# Epoch 3/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1675204.0000 - root_mean_squared_error: 1294.2968
# Epoch 4/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1535397.8750 - root_mean_squared_error: 1239.1117
# Epoch 5/50
# 28/28 [==============================] - 0s 2ms/step - loss: 900282.0000 - root_mean_squared_error: 948.8319
# Epoch 6/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1648746.8750 - root_mean_squared_error: 1284.0354
# Epoch 7/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1014883.0625 - root_mean_squared_error: 1007.4141
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1307157.3750 - root_mean_squared_error: 1143.3098
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 869012.3125 - root_mean_squared_error: 932.2083
# Epoch 10/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1565780.6250 - root_mean_squared_error: 1251.3115
# Epoch 11/50
# 28/28 [==============================] - 0s 1ms/step - loss: 891853.0625 - root_mean_squared_error: 944.3797
# Epoch 12/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1708913.5000 - root_mean_squared_error: 1307.2542
# Epoch 13/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1208731.0000 - root_mean_squared_error: 1099.4230
# Epoch 14/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1043072.0000 - root_mean_squared_error: 1021.3090
# Epoch 15/50
# 28/28 [==============================] - 0s 1ms/step - loss: 852066.6875 - root_mean_squared_error: 923.0746
# Epoch 16/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1317252.3750 - root_mean_squared_error: 1147.7162
# Epoch 17/50
# 28/28 [==============================] - 0s 2ms/step - loss: 828051.5625 - root_mean_squared_error: 909.9733
# Epoch 18/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1135849.2500 - root_mean_squared_error: 1065.7623
# Epoch 19/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1963101.0000 - root_mean_squared_error: 1401.1071
# Epoch 20/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1483633.7500 - root_mean_squared_error: 1218.0450
# Epoch 21/50
# 28/28 [==============================] - 0s 2ms/step - loss: 611956.1250 - root_mean_squared_error: 782.2762
# Epoch 22/50
# 28/28 [==============================] - 0s 1ms/step - loss: 942985.4375 - root_mean_squared_error: 971.0744
# Epoch 23/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1796813.7500 - root_mean_squared_error: 1340.4528
# Epoch 24/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1358041.0000 - root_mean_squared_error: 1165.3502
# Epoch 25/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1515078.0000 - root_mean_squared_error: 1230.8850
# Epoch 26/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1400259.8750 - root_mean_squared_error: 1183.3258
# Epoch 27/50
# 28/28 [==============================] - 0s 3ms/step - loss: 999549.0625 - root_mean_squared_error: 999.7745
# Epoch 28/50
# 28/28 [==============================] - 0s 3ms/step - loss: 442641.5000 - root_mean_squared_error: 665.3131
# Epoch 29/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1470487.1250 - root_mean_squared_error: 1212.6365
# Epoch 30/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1415818.1250 - root_mean_squared_error: 1189.8816
# Epoch 31/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1116432.6250 - root_mean_squared_error: 1056.6138
# Epoch 32/50
# 28/28 [==============================] - 0s 3ms/step - loss: 2071122.1250 - root_mean_squared_error: 1439.1394
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1113512.1250 - root_mean_squared_error: 1055.2308
# Epoch 34/50
# 28/28 [==============================] - 0s 3ms/step - loss: 878029.4375 - root_mean_squared_error: 937.0322
# Epoch 35/50
# 28/28 [==============================] - 0s 2ms/step - loss: 665103.6250 - root_mean_squared_error: 815.5389
# Epoch 36/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1412471.1250 - root_mean_squared_error: 1188.4742
# Epoch 37/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1554254.8750 - root_mean_squared_error: 1246.6976
# Epoch 38/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1580143.6250 - root_mean_squared_error: 1257.0376
# Epoch 39/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1245381.1250 - root_mean_squared_error: 1115.9664
# Epoch 40/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1295158.1250 - root_mean_squared_error: 1138.0502
# Epoch 41/50
# 28/28 [==============================] - 0s 3ms/step - loss: 2043420.5000 - root_mean_squared_error: 1429.4825
# Epoch 42/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1777.0353 - root_mean_squared_error: 42.1549
# Epoch 43/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1646593.3750 - root_mean_squared_error: 1283.1965
# Epoch 44/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1079371.0000 - root_mean_squared_error: 1038.9279
# Epoch 45/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1126310.2500 - root_mean_squared_error: 1061.2777
# Epoch 46/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1687451.6250 - root_mean_squared_error: 1299.0195
# Epoch 47/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1234961.5000 - root_mean_squared_error: 1111.2882
# Epoch 48/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1124598.7500 - root_mean_squared_error: 1060.4709
# Epoch 49/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1265661.2500 - root_mean_squared_error: 1125.0161
# Epoch 50/50
# 28/28 [==============================] - 0s 2ms/step - loss: 990334.6875 - root_mean_squared_error: 995.1556
#
# The learned weight for your model is -0.0313
# The learned bias for your model is 0.4407
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
plt.plot(training_df['Kms'],training_df['Present_Price'])

# %%
def predict_car_values(n, feature, label):
  """Predict car values based on a feature."""

  batch = training_df[feature][100:100 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature      label          predicted")
  print("  kms     SellingPrice        price  ")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.2f %6.2f %15.2f" % (training_df[feature][100 + i],
                                   training_df[label][100 + i],
                                   predicted_values[i][0] ))

# %%
predict_car_values(5, my_feature, my_label)
# Out:
# feature      label          predicted
#   kms     SellingPrice        price
# --------------------------------------
# 98000.00   1.73        -3161.52
# 99000.00   1.70        -3192.83
# 100000.00   1.67        -3224.14
# 101000.00   1.63        -3255.44
# 102000.00   1.60        -3286.75

# %%
# Define a synthetic feature
training_df["kms_scaled_1000"] = training_df["Kms"]/1000

training_df["Synthetic_Feature"] = training_df["kms_scaled_1000"]

my_feature = "Synthetic_Feature"
my_label="Present_Price"

print(training_df)

# Tune the hyperparameters.

#learning_rate = 0.005(correct)
learning_rate = 0.006

#epochs = 150(correct)
epochs = 200

#batch_size = 10(correct)
batch_size = 10

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, mae = train_model(my_model, training_df,
                                        my_feature, my_label,
                                        epochs, batch_size)

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, mae)
predict_car_values(5, my_feature, my_label)
# Out:
#          Kms  Present_Price  kms_scaled_1000  Synthetic_Feature
# 0     1000.0            5.0              1.0                1.0
# 1     2000.0            4.9              2.0                2.0
# 2     3000.0            4.9              3.0                3.0
# 3     4000.0            4.9              4.0                4.0
# 4     5000.0            4.8              5.0                5.0
# ..       ...            ...              ...                ...
# 135 132000.0            0.6            132.0              132.0
# 136 133000.0            0.6            133.0              133.0
# 137 134000.0            0.5            134.0              134.0
# 138 135000.0            0.5            135.0              135.0
# 139 136000.0            0.5            136.0              136.0
#
# [136 rows x 4 columns]
# Epoch 1/200
# 14/14 [==============================] - 0s 2ms/step - loss: 391.3920 - root_mean_squared_error: 19.7836
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 172.0013 - root_mean_squared_error: 13.1149
# Epoch 3/200
# 14/14 [==============================] - 0s 2ms/step - loss: 69.5027 - root_mean_squared_error: 8.3368
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 22.4686 - root_mean_squared_error: 4.7401
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 8.5330 - root_mean_squared_error: 2.9211
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.8723 - root_mean_squared_error: 2.6215
# Epoch 7/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.6865 - root_mean_squared_error: 2.5858
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.5320 - root_mean_squared_error: 2.5558
# Epoch 9/200
# 14/14 [==============================] - 0s 3ms/step - loss: 6.4418 - root_mean_squared_error: 2.5381
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.2549 - root_mean_squared_error: 2.5010
# Epoch 11/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.1190 - root_mean_squared_error: 2.4737
# Epoch 12/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.9157 - root_mean_squared_error: 2.4322
# Epoch 13/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.7651 - root_mean_squared_error: 2.4011
# Epoch 14/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.7197 - root_mean_squared_error: 2.3916
# Epoch 15/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.5169 - root_mean_squared_error: 2.3488
# Epoch 16/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.2239 - root_mean_squared_error: 2.2856
# Epoch 17/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.1820 - root_mean_squared_error: 2.2764
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.9588 - root_mean_squared_error: 2.2268
# Epoch 19/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.9063 - root_mean_squared_error: 2.2150
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.6919 - root_mean_squared_error: 2.1661
# Epoch 21/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.6255 - root_mean_squared_error: 2.1507
# Epoch 22/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.3573 - root_mean_squared_error: 2.0874
# Epoch 23/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.1766 - root_mean_squared_error: 2.0437
# Epoch 24/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.2771 - root_mean_squared_error: 2.0681
# Epoch 25/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.0624 - root_mean_squared_error: 2.0155
# Epoch 26/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.8270 - root_mean_squared_error: 1.9563
# Epoch 27/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.7098 - root_mean_squared_error: 1.9261
# Epoch 28/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.6789 - root_mean_squared_error: 1.9180
# Epoch 29/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4306 - root_mean_squared_error: 1.8522
# Epoch 30/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.2169 - root_mean_squared_error: 1.7936
# Epoch 31/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1631 - root_mean_squared_error: 1.7785
# Epoch 32/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.0853 - root_mean_squared_error: 1.7565
# Epoch 33/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1260 - root_mean_squared_error: 1.7681
# Epoch 34/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8453 - root_mean_squared_error: 1.6868
# Epoch 35/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7244 - root_mean_squared_error: 1.6506
# Epoch 36/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.5530 - root_mean_squared_error: 1.5978
# Epoch 37/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6371 - root_mean_squared_error: 1.6239
# Epoch 38/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4330 - root_mean_squared_error: 1.5598
# Epoch 39/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2751 - root_mean_squared_error: 1.5083
# Epoch 40/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1805 - root_mean_squared_error: 1.4767
# Epoch 41/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0364 - root_mean_squared_error: 1.4270
# Epoch 42/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0208 - root_mean_squared_error: 1.4216
# Epoch 43/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8727 - root_mean_squared_error: 1.3685
# Epoch 44/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8525 - root_mean_squared_error: 1.3611
# Epoch 45/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7207 - root_mean_squared_error: 1.3118
# Epoch 46/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6244 - root_mean_squared_error: 1.2745
# Epoch 47/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6365 - root_mean_squared_error: 1.2792
# Epoch 48/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4092 - root_mean_squared_error: 1.1871
# Epoch 49/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4428 - root_mean_squared_error: 1.2012
# Epoch 50/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2946 - root_mean_squared_error: 1.1378
# Epoch 51/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2211 - root_mean_squared_error: 1.1050
# Epoch 52/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2158 - root_mean_squared_error: 1.1026
# Epoch 53/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0675 - root_mean_squared_error: 1.0332
# Epoch 54/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0781 - root_mean_squared_error: 1.0383
# Epoch 55/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9677 - root_mean_squared_error: 0.9837
# Epoch 56/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9434 - root_mean_squared_error: 0.9713
# Epoch 57/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8564 - root_mean_squared_error: 0.9254
# Epoch 58/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7981 - root_mean_squared_error: 0.8934
# Epoch 59/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7091 - root_mean_squared_error: 0.8421
# Epoch 60/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6830 - root_mean_squared_error: 0.8264
# Epoch 61/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6766 - root_mean_squared_error: 0.8225
# Epoch 62/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5546 - root_mean_squared_error: 0.7447
# Epoch 63/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5991 - root_mean_squared_error: 0.7740
# Epoch 64/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5007 - root_mean_squared_error: 0.7076
# Epoch 65/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4722 - root_mean_squared_error: 0.6872
# Epoch 66/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4382 - root_mean_squared_error: 0.6620
# Epoch 67/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3978 - root_mean_squared_error: 0.6307
# Epoch 68/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3912 - root_mean_squared_error: 0.6254
# Epoch 69/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2962 - root_mean_squared_error: 0.5443
# Epoch 70/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3360 - root_mean_squared_error: 0.5797
# Epoch 71/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2872 - root_mean_squared_error: 0.5359
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2810 - root_mean_squared_error: 0.5301
# Epoch 73/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2242 - root_mean_squared_error: 0.4735
# Epoch 74/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2097 - root_mean_squared_error: 0.4579
# Epoch 75/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1906 - root_mean_squared_error: 0.4366
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1599 - root_mean_squared_error: 0.3999
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1645 - root_mean_squared_error: 0.4055
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1299 - root_mean_squared_error: 0.3605
# Epoch 79/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1304 - root_mean_squared_error: 0.3612
# Epoch 80/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1055 - root_mean_squared_error: 0.3248
# Epoch 81/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1146 - root_mean_squared_error: 0.3386
# Epoch 82/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0965 - root_mean_squared_error: 0.3106
# Epoch 83/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0989 - root_mean_squared_error: 0.3144
# Epoch 84/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0679 - root_mean_squared_error: 0.2605
# Epoch 85/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1148 - root_mean_squared_error: 0.3388
# Epoch 86/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0876 - root_mean_squared_error: 0.2960
# Epoch 87/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0318 - root_mean_squared_error: 0.1784
# Epoch 88/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0951 - root_mean_squared_error: 0.3084
# Epoch 89/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841
# Epoch 90/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1086 - root_mean_squared_error: 0.3295
# Epoch 91/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0322 - root_mean_squared_error: 0.1794
# Epoch 92/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0512 - root_mean_squared_error: 0.2263
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0766 - root_mean_squared_error: 0.2767
# Epoch 94/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0608 - root_mean_squared_error: 0.2466
# Epoch 95/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 96/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0590 - root_mean_squared_error: 0.2429
# Epoch 97/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0365 - root_mean_squared_error: 0.1912
# Epoch 98/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1031 - root_mean_squared_error: 0.3211
# Epoch 99/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0433 - root_mean_squared_error: 0.2081
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 101/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468
# Epoch 102/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 103/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0861 - root_mean_squared_error: 0.2934
# Epoch 104/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324
# Epoch 105/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0642 - root_mean_squared_error: 0.2535
# Epoch 106/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0802 - root_mean_squared_error: 0.2832
# Epoch 107/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 108/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0795 - root_mean_squared_error: 0.2819
# Epoch 109/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365
# Epoch 110/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0648 - root_mean_squared_error: 0.2547
# Epoch 111/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0837 - root_mean_squared_error: 0.2893
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184
# Epoch 113/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0370 - root_mean_squared_error: 0.1923
# Epoch 114/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0841 - root_mean_squared_error: 0.2900
# Epoch 115/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441
# Epoch 116/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0342 - root_mean_squared_error: 0.1848
# Epoch 117/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0489 - root_mean_squared_error: 0.2211
# Epoch 118/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594
# Epoch 119/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0581 - root_mean_squared_error: 0.2409
# Epoch 120/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743
# Epoch 121/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0714 - root_mean_squared_error: 0.2673
# Epoch 122/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0786 - root_mean_squared_error: 0.2804
# Epoch 123/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0023 - root_mean_squared_error: 0.0481
# Epoch 124/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377
# Epoch 125/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422
# Epoch 126/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0892 - root_mean_squared_error: 0.2986
# Epoch 127/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0302 - root_mean_squared_error: 0.1738
# Epoch 128/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0571 - root_mean_squared_error: 0.2390
# Epoch 129/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0868 - root_mean_squared_error: 0.2946
# Epoch 130/200
# 14/14 [==============================] - 0s 3ms/step - loss: 8.6126e-04 - root_mean_squared_error: 0.0293
# Epoch 131/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0905 - root_mean_squared_error: 0.3008
# Epoch 132/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260
# Epoch 133/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808
# Epoch 134/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0552 - root_mean_squared_error: 0.2350
# Epoch 135/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0711 - root_mean_squared_error: 0.2666
# Epoch 136/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0647 - root_mean_squared_error: 0.2543
# Epoch 137/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0375 - root_mean_squared_error: 0.1936
# Epoch 138/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0510 - root_mean_squared_error: 0.2259
# Epoch 139/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673
# Epoch 140/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0579 - root_mean_squared_error: 0.2406
# Epoch 141/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0620 - root_mean_squared_error: 0.2490
# Epoch 142/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1006 - root_mean_squared_error: 0.3172
# Epoch 143/200
# 14/14 [==============================] - 0s 2ms/step - loss: 9.1646e-06 - root_mean_squared_error: 0.0030
# Epoch 144/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0878 - root_mean_squared_error: 0.2963
# Epoch 145/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817
# Epoch 146/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410
# Epoch 147/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0675 - root_mean_squared_error: 0.2598
# Epoch 148/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0764 - root_mean_squared_error: 0.2763
# Epoch 149/200
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4628e-04 - root_mean_squared_error: 0.0121
# Epoch 150/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1029 - root_mean_squared_error: 0.3208
# Epoch 151/200
# 14/14 [==============================] - 0s 6ms/step - loss: 3.4749e-05 - root_mean_squared_error: 0.0059
# Epoch 152/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1230 - root_mean_squared_error: 0.3507
# Epoch 153/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1878e-07 - root_mean_squared_error: 5.6461e-04
# Epoch 154/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 155/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047
# Epoch 156/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0542 - root_mean_squared_error: 0.2329
# Epoch 157/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0926 - root_mean_squared_error: 0.3043
# Epoch 158/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636
# Epoch 159/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0773 - root_mean_squared_error: 0.2779
# Epoch 160/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0736 - root_mean_squared_error: 0.2714
# Epoch 161/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964
# Epoch 162/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0710 - root_mean_squared_error: 0.2664
# Epoch 163/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0316 - root_mean_squared_error: 0.1779
# Epoch 164/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 165/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0525 - root_mean_squared_error: 0.2292
# Epoch 166/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862
# Epoch 167/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0503 - root_mean_squared_error: 0.2244
# Epoch 168/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0562 - root_mean_squared_error: 0.2371
# Epoch 169/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499
# Epoch 170/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1074 - root_mean_squared_error: 0.3278
# Epoch 171/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.6774e-06 - root_mean_squared_error: 0.0024
# Epoch 172/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0925 - root_mean_squared_error: 0.3042
# Epoch 173/200
# 14/14 [==============================] - 0s 2ms/step - loss: 9.5112e-04 - root_mean_squared_error: 0.0308
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0937 - root_mean_squared_error: 0.3061
# Epoch 175/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0542 - root_mean_squared_error: 0.2327
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0294 - root_mean_squared_error: 0.1714
# Epoch 177/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0329 - root_mean_squared_error: 0.1814
# Epoch 178/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0663 - root_mean_squared_error: 0.2575
# Epoch 179/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0823 - root_mean_squared_error: 0.2869
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0030 - root_mean_squared_error: 0.0543
# Epoch 181/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0566 - root_mean_squared_error: 0.2380
# Epoch 182/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0582 - root_mean_squared_error: 0.2412
# Epoch 183/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0294 - root_mean_squared_error: 0.1714
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0426 - root_mean_squared_error: 0.2063
# Epoch 185/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0793 - root_mean_squared_error: 0.2816
# Epoch 186/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217
# Epoch 187/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0577 - root_mean_squared_error: 0.2402
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0944 - root_mean_squared_error: 0.3073
# Epoch 189/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.7528e-06 - root_mean_squared_error: 0.0026
# Epoch 190/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0635 - root_mean_squared_error: 0.2520
# Epoch 191/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0697 - root_mean_squared_error: 0.2640
# Epoch 192/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184
# Epoch 193/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0752 - root_mean_squared_error: 0.2743
# Epoch 194/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0594 - root_mean_squared_error: 0.2436
# Epoch 195/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0154 - root_mean_squared_error: 0.1243
# Epoch 196/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0685 - root_mean_squared_error: 0.2617
# Epoch 197/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0409 - root_mean_squared_error: 0.2024
# Epoch 198/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632
# Epoch 199/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0870 - root_mean_squared_error: 0.2950
# Epoch 200/200
# 14/14 [==============================] - 0s 2ms/step - loss: 7.2617e-05 - root_mean_squared_error: 0.0085
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# feature      label          predicted
#   kms     SellingPrice        price
# --------------------------------------
# 98.00   1.73            1.61
# 99.00   1.70            1.58
# 100.00   1.67            1.55
# 101.00   1.63            1.51
# 102.00   1.60            1.48
